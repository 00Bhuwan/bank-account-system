# %%
import json
import os
os.getcwd()
# Out:
# 'C:\\Users\\9849i\\IdeaProjects\\PythonProject'

# %%
import json
dict1 = {"1": "ram", "2": "shtam"}
dict2 = {"keta": "keti"}
del dict1
dict1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       3 dict2 = {"keta": "keti"}
#       4 del dict1
# ----> 5 dict1
#
# NameError: name 'dict1' is not defined
